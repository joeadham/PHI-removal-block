# %%
import phi_removal as pr

# %%
import timeit
start_time = timeit.default_timer()
pr.remove_phi(r"C:\Users\youse\OneDrive\Desktop\GP\SCANS")
elapsed = timeit.default_timer() - start_time
# Out:
# Total number of DICOM files: 0

# %%
pr.display_dicom_series_info(r"C:\\Studies\\Graduation-Project\Ain Shams data\\case 1 neuroblastoa mef 294 follow up")
# Out:
# Series Description: Recon 3: Abdomen Pelvis, Series Number: 4, Count: 161
# Series Description: THIN, Series Number: 6, Count: 521
# Series Description: Abdomen Pelvis, Series Number: 2, Count: 66
# Series Description: THIN, Series Number: 3, Count: 521
# Series Description: Abdomen Pelvis, Series Number: 5, Count: 66
# Series Description: Dose Report, Series Number: 999, Count: 1
# Series Description: Scout, Series Number: 1, Count: 2
# Series Description: Recon 3: Abdomen Pelvis, Series Number: 7, Count: 161
# Series Description: FUJI Presentation State - ANNOTATIONS, Series Number: None, Count: 1
# Series Description: FUJI Presentation State - SNAPSHOT, Series Number: None, Count: 2
# Series Description: FUJI Basic Text SR for HL7 Radiological Report, Series Number: 999, Count: 1
# Patient ID: 20231102140557881
# Patient Birth Date: 20171103
# Patient Name: Unknown1^Unknown1

# %%
pr.remove_phi(r"C:\\Studies\\Graduation-Project\Ain Shams data\\case 1 neuroblastoa mef 294 follow up")
# Out:
# Total number of DICOM files: 1503
# Parent Folder: case 1 neuroblastoa mef 294 follow up, Series Path: C:\\Studies\\Graduation-Project\Ain Shams data\\case 1 neuroblastoa mef 294 follow up
# File copied: C:\\Studies\\Graduation-Project\Ain Shams data\\case 1 neuroblastoa mef 294 follow up\00000001 to c:\Studies\Graduation-Project\Codes\PHI-removal-block\case 1 neuroblastoa mef 294 follow up PHI_REMOVED\00000001
# File copied: C:\\Studies\\Graduation-Project\Ain Shams data\\case 1 neuroblastoa mef 294 follow up\00000002 to c:\Studies\Graduation-Project\Codes\PHI-removal-block\case 1 neuroblastoa mef 294 follow up PHI_REMOVED\00000002
# File copied: C:\\Studies\\Graduation-Project\Ain Shams data\\case 1 neuroblastoa mef 294 follow up\00000003 to c:\Studies\Graduation-Project\Codes\PHI-removal-block\case 1 neuroblastoa mef 294 follow up PHI_REMOVED\00000003
# ...

# %%
pr.display_dicom_series_info(r"c:\Studies\Graduation-Project\Codes\PHI-removal-block\case 1 neuroblastoa mef 294 follow up PHI_REMOVED")
# Out:
# Series Description: Recon 3: Abdomen Pelvis, Series Number: 4, Count: 161
# Series Description: THIN, Series Number: 6, Count: 521
# Series Description: Abdomen Pelvis, Series Number: 2, Count: 66
# Series Description: THIN, Series Number: 3, Count: 521
# Series Description: Abdomen Pelvis, Series Number: 5, Count: 66
# Series Description: Scout, Series Number: 1, Count: 2
# Series Description: Recon 3: Abdomen Pelvis, Series Number: 7, Count: 161
# Series Description: FUJI Presentation State - ANNOTATIONS, Series Number: None, Count: 1
# Series Description: FUJI Presentation State - SNAPSHOT, Series Number: None, Count: 2
# Patient ID: ANONYMOUS
# Patient Birth Date: 20231218
# Patient Name: ANONYMOUS
